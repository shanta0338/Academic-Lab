# %%
import numpy as np
import pandas as pd

# %%
value = list([45, 70, 70, 55, 75, 73, 70, 65, 68, 60, 74, 83, 80, 58, 68, 85, 90, 64, 75, 82 ])
value.sort()
print(value)
# Out:
# [45, 55, 58, 60, 64, 65, 68, 68, 70, 70, 70, 73, 74, 75, 75, 80, 82, 83, 85, 90]
