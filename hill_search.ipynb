# %%
def f(x):
    return -2*x+4


x_curr = 6
step_size = 0.5

for i in range(50):
    left_x = x_curr - step_size
    right_x = x_curr + step_size
    eval_x_init = f(x_curr)
    eval_left = f(left_x)
    eval_right = f(right_x)
    print(
        f'epoch {i} left value: {eval_left} right value: {eval_right} current value: {eval_x_init}')
    if eval_left > eval_x_init:
        x_curr = left_x
    elif eval_right > eval_x_init:
        x_curr = right_x
    else:
        break
# Out:
# epoch 0 left value: -7.0 right value: -9.0 current value: -8
# epoch 1 left value: -6.0 right value: -8.0 current value: -7.0
# epoch 2 left value: -5.0 right value: -7.0 current value: -6.0
# epoch 3 left value: -4.0 right value: -6.0 current value: -5.0
# epoch 4 left value: -3.0 right value: -5.0 current value: -4.0
# epoch 5 left value: -2.0 right value: -4.0 current value: -3.0
# epoch 6 left value: -1.0 right value: -3.0 current value: -2.0
# epoch 7 left value: 0.0 right value: -2.0 current value: -1.0
# epoch 8 left value: 1.0 right value: -1.0 current value: 0.0
# epoch 9 left value: 2.0 right value: 0.0 current value: 1.0
# epoch 10 left value: 3.0 right value: 1.0 current value: 2.0
# epoch 11 left value: 4.0 right value: 2.0 current value: 3.0
# epoch 12 left value: 5.0 right value: 3.0 current value: 4.0
# epoch 13 left value: 6.0 right value: 4.0 current value: 5.0
# epoch 14 left value: 7.0 right value: 5.0 current value: 6.0
# ...
