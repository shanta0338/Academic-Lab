# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing file

# %%
df = pd.read_csv(r"C:\Users\Shant\OneDrive\Documents\Dataset\StressLevelDataset.csv")

# %%
df.head()
# Out:
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0             14         20.0                      0          11         2
# 1             15          8.0                      1          15         5
# 2             12         18.0                      1          14         2
# 3             16         12.0                      1          15         4
# 4             16         28.0                      0           7         2
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 0               1              2                4.0            2
# 1               3              1                4.0            3
# 2               1              2                2.0            2
# 3               3              1                NaN            4
# 4               3              5                NaN            3
#
#    living_conditions  ...  basic_needs  academic_performance  study_load  \
# ...

# %% [markdown]
# ## Data analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   anxiety_level                 1100 non-null   int64
#  1   self_esteem                   963 non-null    float64
#  2   mental_health_history         1100 non-null   int64
#  3   depression                    1100 non-null   int64
#  4   headache                      1100 non-null   int64
#  5   blood_pressure                1100 non-null   int64
#  6   sleep_quality                 1100 non-null   int64
#  7   breathing_problem             905 non-null    float64
#  8   noise_level                   1100 non-null   int64
#  9   living_conditions             1100 non-null   int64
#  10  safety                        1100 non-null   int64
#  11  basic_needs                   93 non-null     float64
# ...

# %%
df.describe()
# Out:
#        anxiety_level  self_esteem  mental_health_history   depression  \
# count    1100.000000   963.000000            1100.000000  1100.000000
# mean       11.063636    17.673936               0.492727    12.555455
# std         6.117558     8.956793               0.500175     7.727008
# min         0.000000     0.000000               0.000000     0.000000
# 25%         6.000000    11.000000               0.000000     6.000000
# 50%        11.000000    19.000000               0.000000    12.000000
# 75%        16.000000    25.000000               1.000000    19.000000
# max        21.000000    30.000000               1.000000    27.000000
#
#           headache  blood_pressure  sleep_quality  breathing_problem  \
# count  1100.000000     1100.000000    1100.000000         905.000000
# mean      2.508182        2.181818       2.660000           2.737017
# std       1.409356        0.833575       1.548383           1.424893
# ...

# %%
df.columns
# Out:
# Index(['anxiety_level', 'self_esteem', 'mental_health_history', 'depression',
#        'headache', 'blood_pressure', 'sleep_quality', 'breathing_problem',
#        'noise_level', 'living_conditions', 'safety', 'basic_needs',
#        'academic_performance', 'study_load', 'teacher_student_relationship',
#        'future_career_concerns', 'social_support', 'peer_pressure',
#        'extracurricular_activities', 'bullying', 'stress_level'],
#       dtype='object')

# %% [markdown]
# ## Hadeling Missing Values

# %%
print(df['self_esteem'].isnull().sum())
print(df['breathing_problem'].isnull().sum())
print(df['basic_needs'].isnull().sum())
print(df['future_career_concerns'].isnull().sum())
# Out:
# 137
# 195
# 1007
# 360

# %%
print(f"Mean of Self Esteem: {df['self_esteem'].mean()}")
print(f"Meadian of Self Esteem: {df['self_esteem'].median()}")
print(f"Mode of Self Esteem: {df['self_esteem'].mode()}")
# Out:
# Mean of Self Esteem: 17.673935617860852
# Meadian of Self Esteem: 19.0
# Mode of Self Esteem: 0    25.0
# Name: self_esteem, dtype: float64

# %% [markdown]
# ### I will apply mean reason being the max value of Self Esteem is 30, mean is perfect for this circumstances

# %%
df['self_esteem'].fillna(df['self_esteem'].mean(), inplace=True)
# Out:
# C:\Users\Shant\AppData\Local\Temp\ipykernel_16336\4130730580.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['self_esteem'].fillna(df['self_esteem'].mean(), inplace=True)

# %%
print(f"Mean of Basic Need: {df['basic_needs'].mean()}")
print(f"Meadian of Basic Need: {df['basic_needs'].median()}")
print(f"Mode of Basic Need: {df['basic_needs'].mode()}")
# Out:
# Mean of Basic Need: 3.010752688172043
# Meadian of Basic Need: 3.0
# Mode of Basic Need: 0    2.0
# Name: basic_needs, dtype: float64

# %%
print(f"Max Value: {df['basic_needs'].max()}, Minimum Value: {df['basic_needs'].min()}")
# Out:
# Max Value: 5.0, Minimum Value: 1.0

# %% [markdown]
# ### I will apply mean reason being the max value of Basic need is 5, median is perfect for this circumstances

# %%
df['basic_needs'].fillna(df['basic_needs'].median(), inplace=True)
# Out:
# C:\Users\Shant\AppData\Local\Temp\ipykernel_16336\2115846938.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['basic_needs'].fillna(df['basic_needs'].median(), inplace=True)

# %%
print(f"Mean of Basic Need: {df['future_career_concerns'].mean()}")
print(f"Meadian of Basic Need: {df['future_career_concerns'].median()}")
print(f"Mode of Basic Need: {df['future_career_concerns'].mode()}")
# Out:
# Mean of Basic Need: 2.641891891891892
# Meadian of Basic Need: 2.0
# Mode of Basic Need: 0    1.0
# Name: future_career_concerns, dtype: float64

# %%
print(f"Max Value: {df['future_career_concerns'].max()}, Minimum Value: {df['future_career_concerns'].min()}")
# Out:
# Max Value: 5.0, Minimum Value: 0.0

# %% [markdown]
# ### I will apply mean reason being the max value of future_career_concerns is 30, mean is perfect for this circumstances

# %%
df['future_career_concerns'].fillna(df['future_career_concerns'].median(), inplace=True)
# Out:
# C:\Users\Shant\AppData\Local\Temp\ipykernel_16336\966798276.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['future_career_concerns'].fillna(df['future_career_concerns'].median(), inplace=True)

# %%
print(f"Mean of Breathing Problem: {df['breathing_problem'].mean()}")
print(f"Meadian of Breathing Problem: {df['breathing_problem'].median()}")
print(f"Mode of Breathing Problem: {df['breathing_problem'].mode()}")
# Out:
# Mean of Breathing Problem: 2.737016574585635
# Meadian of Breathing Problem: 2.0
# Mode of Breathing Problem: 0    2.0
# Name: breathing_problem, dtype: float64

# %%
print(f"Max Value: {df['breathing_problem'].max()}, Minimum Value: {df['breathing_problem'].min()}")
# Out:
# Max Value: 5.0, Minimum Value: 0.0

# %% [markdown]
# ## The data points are in breathing_problem is symmetric

# %%
df['breathing_problem'].fillna(df['breathing_problem'].median(), inplace=True)
# Out:
# C:\Users\Shant\AppData\Local\Temp\ipykernel_16336\2490329876.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['breathing_problem'].fillna(df['breathing_problem'].median(), inplace=True)
